# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.manifold import TSNE
from sklearn.decomposition import TruncatedSVD

# %%
data = pd.read_csv('data/telecom_churn.csv')

# %%
X , y = data.drop('Churn', axis=1), data['Churn']

# %%
c_20 = TSNE(n_components=2, perplexity=20, verbose=2).fit_transform(X)

tsne_vis = pd.concat([pd.DataFrame(c_20), y], axis=1)

sns.scatterplot(x=tsne_vis.iloc[:,0],y=tsne_vis.iloc[:,1], hue=tsne_vis.Churn, palette='Set1')
# Out:
# c:\Users\Krzysztof\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# c:\Users\Krzysztof\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 61 nearest neighbors...
# [t-SNE] Indexed 3333 samples in 0.010s...
# [t-SNE] Computed neighbors for 3333 samples in 0.101s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3333
# [t-SNE] Computed conditional probabilities for sample 2000 / 3333
# [t-SNE] Computed conditional probabilities for sample 3000 / 3333
# [t-SNE] Computed conditional probabilities for sample 3333 / 3333
# [t-SNE] Mean sigma: 9.922449
# [t-SNE] Computed conditional probabilities in 0.110s
# [t-SNE] Iteration 50: error = 85.4711456, gradient norm = 0.0659211 (50 iterations in 0.959s)
# [t-SNE] Iteration 100: error = 77.2163239, gradient norm = 0.0015846 (50 iterations in 0.941s)
# [t-SNE] Iteration 150: error = 77.0444260, gradient norm = 0.0001293 (50 iterations in 0.997s)
# [t-SNE] Iteration 200: error = 77.0354996, gradient norm = 0.0000474 (50 iterations in 0.971s)
# [t-SNE] Iteration 250: error = 77.0351105, gradient norm = 0.0000547 (50 iterations in 0.997s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 77.035110
# [t-SNE] Iteration 300: error = 1.8989308, gradient norm = 0.0011736 (50 iterations in 1.061s)
# [t-SNE] Iteration 350: error = 1.5392907, gradient norm = 0.0004518 (50 iterations in 0.979s)
# [t-SNE] Iteration 400: error = 1.4044082, gradient norm = 0.0002490 (50 iterations in 0.876s)
# [t-SNE] Iteration 450: error = 1.3394836, gradient norm = 0.0001667 (50 iterations in 0.923s)
# [t-SNE] Iteration 500: error = 1.3044251, gradient norm = 0.0001241 (50 iterations in 0.945s)
# [t-SNE] Iteration 550: error = 1.2837712, gradient norm = 0.0001102 (50 iterations in 0.914s)
# [t-SNE] Iteration 600: error = 1.2713170, gradient norm = 0.0000956 (50 iterations in 0.882s)
# [t-SNE] Iteration 650: error = 1.2632519, gradient norm = 0.0000845 (50 iterations in 0.925s)
# [t-SNE] Iteration 700: error = 1.2571558, gradient norm = 0.0000818 (50 iterations in 0.851s)
# [t-SNE] Iteration 750: error = 1.2526478, gradient norm = 0.0000700 (50 iterations in 0.847s)
# [t-SNE] Iteration 800: error = 1.2490467, gradient norm = 0.0000783 (50 iterations in 0.842s)
# [t-SNE] Iteration 850: error = 1.2463074, gradient norm = 0.0000589 (50 iterations in 0.854s)
# [t-SNE] Iteration 900: error = 1.2439713, gradient norm = 0.0000589 (50 iterations in 0.912s)
# [t-SNE] Iteration 950: error = 1.2417783, gradient norm = 0.0000598 (50 iterations in 0.883s)
# [t-SNE] Iteration 1000: error = 1.2401528, gradient norm = 0.0000511 (50 iterations in 0.911s)
# [t-SNE] KL divergence after 1000 iterations: 1.240153
# <AxesSubplot: xlabel='0', ylabel='1'>

# %%
c_30 = TSNE(n_components=2, perplexity=30, verbose=2).fit_transform(X)

tsne_vis = pd.concat([pd.DataFrame(c_30), y], axis=1)

sns.scatterplot(x=tsne_vis.iloc[:,0],y=tsne_vis.iloc[:,1], hue=tsne_vis.Churn, palette='Set1')
# Out:
# c:\Users\Krzysztof\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# c:\Users\Krzysztof\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 3333 samples in 0.008s...
# [t-SNE] Computed neighbors for 3333 samples in 0.102s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3333
# [t-SNE] Computed conditional probabilities for sample 2000 / 3333
# [t-SNE] Computed conditional probabilities for sample 3000 / 3333
# [t-SNE] Computed conditional probabilities for sample 3333 / 3333
# [t-SNE] Mean sigma: 11.239228
# [t-SNE] Computed conditional probabilities in 0.148s
# [t-SNE] Iteration 50: error = 84.7717972, gradient norm = 0.0294407 (50 iterations in 1.422s)
# [t-SNE] Iteration 100: error = 74.3587570, gradient norm = 0.0017870 (50 iterations in 0.981s)
# [t-SNE] Iteration 150: error = 74.2286987, gradient norm = 0.0001450 (50 iterations in 0.969s)
# [t-SNE] Iteration 200: error = 74.2266388, gradient norm = 0.0000935 (50 iterations in 1.014s)
# [t-SNE] Iteration 250: error = 74.2276535, gradient norm = 0.0001840 (50 iterations in 0.949s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 74.227654
# [t-SNE] Iteration 300: error = 1.7292463, gradient norm = 0.0010975 (50 iterations in 0.878s)
# [t-SNE] Iteration 350: error = 1.4428704, gradient norm = 0.0004183 (50 iterations in 0.937s)
# [t-SNE] Iteration 400: error = 1.3411134, gradient norm = 0.0002119 (50 iterations in 0.829s)
# [t-SNE] Iteration 450: error = 1.2928845, gradient norm = 0.0001443 (50 iterations in 0.991s)
# [t-SNE] Iteration 500: error = 1.2677699, gradient norm = 0.0001120 (50 iterations in 1.152s)
# [t-SNE] Iteration 550: error = 1.2541468, gradient norm = 0.0000896 (50 iterations in 1.018s)
# [t-SNE] Iteration 600: error = 1.2459027, gradient norm = 0.0000697 (50 iterations in 1.007s)
# [t-SNE] Iteration 650: error = 1.2402352, gradient norm = 0.0000645 (50 iterations in 1.036s)
# [t-SNE] Iteration 700: error = 1.2363925, gradient norm = 0.0000575 (50 iterations in 1.001s)
# [t-SNE] Iteration 750: error = 1.2337189, gradient norm = 0.0000523 (50 iterations in 0.944s)
# [t-SNE] Iteration 800: error = 1.2315888, gradient norm = 0.0000508 (50 iterations in 0.996s)
# [t-SNE] Iteration 850: error = 1.2298141, gradient norm = 0.0000481 (50 iterations in 1.077s)
# [t-SNE] Iteration 900: error = 1.2285311, gradient norm = 0.0000458 (50 iterations in 0.983s)
# [t-SNE] Iteration 950: error = 1.2276148, gradient norm = 0.0000440 (50 iterations in 0.975s)
# [t-SNE] Iteration 1000: error = 1.2267778, gradient norm = 0.0000371 (50 iterations in 0.997s)
# [t-SNE] KL divergence after 1000 iterations: 1.226778
# <AxesSubplot: xlabel='0', ylabel='1'>

# %%
c_40 = TSNE(n_components=2, perplexity=40, verbose=2).fit_transform(X)

tsne_vis = pd.concat([pd.DataFrame(c_40), y], axis=1)

sns.scatterplot(x=tsne_vis.iloc[:,0],y=tsne_vis.iloc[:,1], hue=tsne_vis.Churn, palette='Set1')
# Out:
# c:\Users\Krzysztof\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# c:\Users\Krzysztof\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 3333 samples in 0.013s...
# [t-SNE] Computed neighbors for 3333 samples in 0.165s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3333
# [t-SNE] Computed conditional probabilities for sample 2000 / 3333
# [t-SNE] Computed conditional probabilities for sample 3000 / 3333
# [t-SNE] Computed conditional probabilities for sample 3333 / 3333
# [t-SNE] Mean sigma: 12.264617
# [t-SNE] Computed conditional probabilities in 0.190s
# [t-SNE] Iteration 50: error = 79.0205460, gradient norm = 0.0516242 (50 iterations in 1.286s)
# [t-SNE] Iteration 100: error = 72.1390839, gradient norm = 0.0003006 (50 iterations in 1.286s)
# [t-SNE] Iteration 150: error = 72.1194992, gradient norm = 0.0000201 (50 iterations in 1.071s)
# [t-SNE] Iteration 200: error = 72.1193848, gradient norm = 0.0000172 (50 iterations in 1.048s)
# [t-SNE] Iteration 250: error = 72.1194305, gradient norm = 0.0000206 (50 iterations in 1.068s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 72.119431
# [t-SNE] Iteration 300: error = 1.6067339, gradient norm = 0.0009927 (50 iterations in 1.141s)
# [t-SNE] Iteration 350: error = 1.3691583, gradient norm = 0.0003644 (50 iterations in 0.936s)
# [t-SNE] Iteration 400: error = 1.2870275, gradient norm = 0.0001969 (50 iterations in 0.921s)
# [t-SNE] Iteration 450: error = 1.2508079, gradient norm = 0.0001207 (50 iterations in 0.947s)
# [t-SNE] Iteration 500: error = 1.2320287, gradient norm = 0.0000921 (50 iterations in 0.921s)
# [t-SNE] Iteration 550: error = 1.2219900, gradient norm = 0.0000765 (50 iterations in 0.922s)
# [t-SNE] Iteration 600: error = 1.2162880, gradient norm = 0.0000649 (50 iterations in 0.920s)
# [t-SNE] Iteration 650: error = 1.2129096, gradient norm = 0.0000576 (50 iterations in 1.003s)
# [t-SNE] Iteration 700: error = 1.2105380, gradient norm = 0.0000526 (50 iterations in 1.051s)
# [t-SNE] Iteration 750: error = 1.2087246, gradient norm = 0.0000720 (50 iterations in 1.432s)
# [t-SNE] Iteration 800: error = 1.2073355, gradient norm = 0.0000463 (50 iterations in 1.367s)
# [t-SNE] Iteration 850: error = 1.2063594, gradient norm = 0.0000377 (50 iterations in 1.156s)
# [t-SNE] Iteration 900: error = 1.2053885, gradient norm = 0.0000406 (50 iterations in 1.163s)
# [t-SNE] Iteration 950: error = 1.2045503, gradient norm = 0.0000345 (50 iterations in 1.097s)
# [t-SNE] Iteration 1000: error = 1.2038238, gradient norm = 0.0000335 (50 iterations in 1.272s)
# [t-SNE] KL divergence after 1000 iterations: 1.203824
# <AxesSubplot: xlabel='0', ylabel='1'>

# %%
c_80 = TSNE(n_components=2, perplexity=80, verbose=2).fit_transform(X)

tsne_vis = pd.concat([pd.DataFrame(c_80), y], axis=1)

sns.scatterplot(x=tsne_vis.iloc[:,0],y=tsne_vis.iloc[:,1], hue=tsne_vis.Churn, palette='Set1')
# Out:
# c:\Users\Krzysztof\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# c:\Users\Krzysztof\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 241 nearest neighbors...
# [t-SNE] Indexed 3333 samples in 0.009s...
# [t-SNE] Computed neighbors for 3333 samples in 0.231s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3333
# [t-SNE] Computed conditional probabilities for sample 2000 / 3333
# [t-SNE] Computed conditional probabilities for sample 3000 / 3333
# [t-SNE] Computed conditional probabilities for sample 3333 / 3333
# [t-SNE] Mean sigma: 15.131224
# [t-SNE] Computed conditional probabilities in 0.541s
# [t-SNE] Iteration 50: error = 73.0551605, gradient norm = 0.0242507 (50 iterations in 1.882s)
# [t-SNE] Iteration 100: error = 66.9483490, gradient norm = 0.0066777 (50 iterations in 2.554s)
# [t-SNE] Iteration 150: error = 66.7869110, gradient norm = 0.0000356 (50 iterations in 2.008s)
# [t-SNE] Iteration 200: error = 66.7867508, gradient norm = 0.0000535 (50 iterations in 1.805s)
# [t-SNE] Iteration 250: error = 66.7864227, gradient norm = 0.0000403 (50 iterations in 1.708s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 66.786423
# [t-SNE] Iteration 300: error = 1.3024607, gradient norm = 0.0007832 (50 iterations in 1.515s)
# [t-SNE] Iteration 350: error = 1.1606034, gradient norm = 0.0002733 (50 iterations in 1.859s)
# [t-SNE] Iteration 400: error = 1.1179104, gradient norm = 0.0001274 (50 iterations in 1.710s)
# [t-SNE] Iteration 450: error = 1.1010025, gradient norm = 0.0000793 (50 iterations in 1.541s)
# [t-SNE] Iteration 500: error = 1.0933758, gradient norm = 0.0000736 (50 iterations in 1.541s)
# [t-SNE] Iteration 550: error = 1.0897546, gradient norm = 0.0000430 (50 iterations in 1.456s)
# [t-SNE] Iteration 600: error = 1.0876622, gradient norm = 0.0000369 (50 iterations in 1.441s)
# [t-SNE] Iteration 650: error = 1.0865238, gradient norm = 0.0000292 (50 iterations in 1.651s)
# [t-SNE] Iteration 700: error = 1.0858015, gradient norm = 0.0000274 (50 iterations in 1.707s)
# [t-SNE] Iteration 750: error = 1.0852748, gradient norm = 0.0000224 (50 iterations in 1.925s)
# [t-SNE] Iteration 800: error = 1.0848464, gradient norm = 0.0000226 (50 iterations in 1.683s)
# [t-SNE] Iteration 850: error = 1.0845435, gradient norm = 0.0000196 (50 iterations in 1.739s)
# [t-SNE] Iteration 900: error = 1.0842839, gradient norm = 0.0000177 (50 iterations in 1.726s)
# [t-SNE] Iteration 950: error = 1.0840361, gradient norm = 0.0000200 (50 iterations in 1.740s)
# [t-SNE] Iteration 1000: error = 1.0838525, gradient norm = 0.0000179 (50 iterations in 1.737s)
# [t-SNE] KL divergence after 1000 iterations: 1.083853
# <AxesSubplot: xlabel='0', ylabel='1'>

# %%
c_10 = TSNE(n_components=2, perplexity=10, verbose=2).fit_transform(X)

tsne_vis = pd.concat([pd.DataFrame(c_10), y], axis=1)

sns.scatterplot(x=tsne_vis.iloc[:,0],y=tsne_vis.iloc[:,1], hue=tsne_vis.Churn, palette='Set1')
# Out:
# c:\Users\Krzysztof\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# c:\Users\Krzysztof\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 3333 samples in 0.008s...
# [t-SNE] Computed neighbors for 3333 samples in 0.057s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3333
# [t-SNE] Computed conditional probabilities for sample 2000 / 3333
# [t-SNE] Computed conditional probabilities for sample 3000 / 3333
# [t-SNE] Computed conditional probabilities for sample 3333 / 3333
# [t-SNE] Mean sigma: 7.925306
# [t-SNE] Computed conditional probabilities in 0.040s
# [t-SNE] Iteration 50: error = 97.6605530, gradient norm = 0.0486901 (50 iterations in 0.712s)
# [t-SNE] Iteration 100: error = 82.8044586, gradient norm = 0.0123596 (50 iterations in 0.587s)
# [t-SNE] Iteration 150: error = 81.3670502, gradient norm = 0.0034831 (50 iterations in 0.565s)
# [t-SNE] Iteration 200: error = 81.1152496, gradient norm = 0.0010319 (50 iterations in 0.573s)
# [t-SNE] Iteration 250: error = 81.0583649, gradient norm = 0.0003909 (50 iterations in 0.574s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 81.058365
# [t-SNE] Iteration 300: error = 2.1885321, gradient norm = 0.0013327 (50 iterations in 0.569s)
# [t-SNE] Iteration 350: error = 1.6883277, gradient norm = 0.0006246 (50 iterations in 0.613s)
# [t-SNE] Iteration 400: error = 1.5007594, gradient norm = 0.0003679 (50 iterations in 0.624s)
# [t-SNE] Iteration 450: error = 1.4047326, gradient norm = 0.0002606 (50 iterations in 0.625s)
# [t-SNE] Iteration 500: error = 1.3466969, gradient norm = 0.0002026 (50 iterations in 0.656s)
# [t-SNE] Iteration 550: error = 1.3080063, gradient norm = 0.0001610 (50 iterations in 0.647s)
# [t-SNE] Iteration 600: error = 1.2809327, gradient norm = 0.0001417 (50 iterations in 0.663s)
# [t-SNE] Iteration 650: error = 1.2611623, gradient norm = 0.0001298 (50 iterations in 0.692s)
# [t-SNE] Iteration 700: error = 1.2459466, gradient norm = 0.0001312 (50 iterations in 0.654s)
# [t-SNE] Iteration 750: error = 1.2347981, gradient norm = 0.0001107 (50 iterations in 0.682s)
# [t-SNE] Iteration 800: error = 1.2261976, gradient norm = 0.0001028 (50 iterations in 0.667s)
# [t-SNE] Iteration 850: error = 1.2186242, gradient norm = 0.0000988 (50 iterations in 0.671s)
# [t-SNE] Iteration 900: error = 1.2122085, gradient norm = 0.0000931 (50 iterations in 0.684s)
# [t-SNE] Iteration 950: error = 1.2070112, gradient norm = 0.0000977 (50 iterations in 0.694s)
# [t-SNE] Iteration 1000: error = 1.2027069, gradient norm = 0.0000858 (50 iterations in 0.666s)
# [t-SNE] KL divergence after 1000 iterations: 1.202707
# <AxesSubplot: xlabel='0', ylabel='1'>

# %%
c_5 = TSNE(n_components=2, perplexity=5, verbose=2).fit_transform(X)

tsne_vis = pd.concat([pd.DataFrame(c_5), y], axis=1)

sns.scatterplot(x=tsne_vis.iloc[:,0],y=tsne_vis.iloc[:,1], hue=tsne_vis.Churn, palette='Set1')
# Out:
# c:\Users\Krzysztof\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# c:\Users\Krzysztof\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\manifold\_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 3333 samples in 0.010s...
# [t-SNE] Computed neighbors for 3333 samples in 0.057s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3333
# [t-SNE] Computed conditional probabilities for sample 2000 / 3333
# [t-SNE] Computed conditional probabilities for sample 3000 / 3333
# [t-SNE] Computed conditional probabilities for sample 3333 / 3333
# [t-SNE] Mean sigma: 6.066273
# [t-SNE] Computed conditional probabilities in 0.021s
# [t-SNE] Iteration 50: error = 105.5932388, gradient norm = 0.0672254 (50 iterations in 0.951s)
# [t-SNE] Iteration 100: error = 88.9011307, gradient norm = 0.0381079 (50 iterations in 0.749s)
# [t-SNE] Iteration 150: error = 85.2935410, gradient norm = 0.0167644 (50 iterations in 0.628s)
# [t-SNE] Iteration 200: error = 84.0007706, gradient norm = 0.0085423 (50 iterations in 0.587s)
# [t-SNE] Iteration 250: error = 83.4240646, gradient norm = 0.0038848 (50 iterations in 0.614s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 83.424065
# [t-SNE] Iteration 300: error = 2.4651923, gradient norm = 0.0015485 (50 iterations in 0.569s)
# [t-SNE] Iteration 350: error = 1.8764039, gradient norm = 0.0008444 (50 iterations in 0.595s)
# [t-SNE] Iteration 400: error = 1.6353130, gradient norm = 0.0005556 (50 iterations in 0.598s)
# [t-SNE] Iteration 450: error = 1.4983517, gradient norm = 0.0004284 (50 iterations in 0.604s)
# [t-SNE] Iteration 500: error = 1.4086107, gradient norm = 0.0003459 (50 iterations in 0.742s)
# [t-SNE] Iteration 550: error = 1.3451598, gradient norm = 0.0002884 (50 iterations in 0.608s)
# [t-SNE] Iteration 600: error = 1.2965206, gradient norm = 0.0002456 (50 iterations in 0.614s)
# [t-SNE] Iteration 650: error = 1.2587852, gradient norm = 0.0002157 (50 iterations in 0.624s)
# [t-SNE] Iteration 700: error = 1.2283866, gradient norm = 0.0001894 (50 iterations in 0.661s)
# [t-SNE] Iteration 750: error = 1.2037908, gradient norm = 0.0001711 (50 iterations in 0.619s)
# [t-SNE] Iteration 800: error = 1.1832246, gradient norm = 0.0001563 (50 iterations in 0.625s)
# [t-SNE] Iteration 850: error = 1.1659093, gradient norm = 0.0001448 (50 iterations in 0.620s)
# [t-SNE] Iteration 900: error = 1.1508892, gradient norm = 0.0001324 (50 iterations in 0.639s)
# [t-SNE] Iteration 950: error = 1.1381630, gradient norm = 0.0001222 (50 iterations in 0.642s)
# [t-SNE] Iteration 1000: error = 1.1270057, gradient norm = 0.0001196 (50 iterations in 0.627s)
# [t-SNE] KL divergence after 1000 iterations: 1.127006
# <AxesSubplot: xlabel='0', ylabel='1'>
